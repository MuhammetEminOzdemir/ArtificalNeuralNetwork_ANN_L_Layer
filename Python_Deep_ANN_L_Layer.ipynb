# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data set

x_l = np.load('X.npy')
Y_l = np.load('Y.npy')

img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[260].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# Join a sequence of arrays along an row axis.
X = np.concatenate((x_l[204:409], x_l[822:1027] ), axis=0) # from 0 to 204 is zero sign and from 205 to 410 is one sign 
z = np.zeros(205)
o = np.ones(205)
Y = np.concatenate((z, o), axis=0).reshape(X.shape[0],1)
print("X shape: " , X.shape)
print("Y shape: " , Y.shape)
# Out:
# X shape:  (410, 64, 64)
# Y shape:  (410, 1)

# %%
# Then lets create x_train, y_train, x_test, y_test arrays
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=42)
number_of_train = X_train.shape[0]
number_of_test = X_test.shape[0]

X_train_flatten = X_train.reshape(number_of_train,X_train.shape[1]*X_train.shape[2])
X_test_flatten = X_test .reshape(number_of_test,X_test.shape[1]*X_test.shape[2])
print("X train flatten",X_train_flatten.shape)
print("X test flatten",X_test_flatten.shape)
# Out:
# X train flatten (348, 4096)
# X test flatten (62, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_train = Y_train.T
y_test = Y_test.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (4096, 348)
# x test:  (4096, 62)
# y train:  (1, 348)
# y test:  (1, 62)

# %%
# short description and example of definition (def)
def dummy(parameter):
    dummy_parameter = parameter + 5
    return dummy_parameter
result = dummy(3)     # result = 8

# lets initialize parameters
# So what we need is dimension 4096 that is number of pixels as a parameter for our initialize method(def)
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w, b

w,b = initialize_weights_and_bias(4096)

# %%
# calculation of z
#z = np.dot(w.T,x_train)+b
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head
y_head = sigmoid(0)
y_head
0.5
# Forward propagation steps:
# find z = w.T*x+b
# y_head = sigmoid(z)
# loss(error) = loss(y,y_head)
# cost = sum(loss)
def forward_propagation(w,b,x_train,y_train):
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z) # probabilistic 0-1
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    return cost

# %%
# Optimization Algorithm with Gradient Descent- Backward propagatio

# In backward propagation we will use y_head that found in forward progation
# Therefore instead of writing backward propagation method, lets combine forward propagation and backward propagation
def forward_backward_propagation(w,b,x_train,y_train):
    # forward propagation
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z)
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    # backward propagation
    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1] # x_train.shape[1]  is for scaling
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]                 # x_train.shape[1]  is for scaling
    gradients = {"derivative_weight": derivative_weight,"derivative_bias": derivative_bias}
    return cost,gradients

# Updating(learning) parameters
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    index = []
    # updating(learning) parameters is number_of_iterarion times
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        # lets update
        w = w - learning_rate * gradients["derivative_weight"]
        b = b - learning_rate * gradients["derivative_bias"]
        if i % 10 == 0:
            cost_list2.append(cost)
            index.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    plt.plot(index,cost_list2)
    plt.xticks(index,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    return parameters, gradients, cost_list
#parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate = 0.009,number_of_iterarion = 200)


 # prediction
def predict(w,b,x_test):
    # x_test is a input for forward propagation
    z = sigmoid(np.dot(w.T,x_test)+b)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(z.shape[1]):
        if z[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1
    return Y_prediction
# predict(parameters["weight"],parameters["bias"],x_test)


def logistic_regression(x_train, y_train, x_test, y_test, learning_rate ,  num_iterations):
    # initialize
    dimension =  x_train.shape[0]  # that is 4096
    w,b = initialize_weights_and_bias(dimension)
    # do not change learning rate
    parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate,num_iterations)
    
    y_prediction_test = predict(parameters["weight"],parameters["bias"],x_test)
    y_prediction_train = predict(parameters["weight"],parameters["bias"],x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.01, num_iterations = 150);
# Out:
# Cost after iteration 0: 14.014222
# Cost after iteration 10: 2.544689
# Cost after iteration 20: 2.577950
# Cost after iteration 30: 2.397999
# Cost after iteration 40: 2.185019
# Cost after iteration 50: 1.968348
# Cost after iteration 60: 1.754195
# Cost after iteration 70: 1.535079
# Cost after iteration 80: 1.297567
# Cost after iteration 90: 1.031919
# Cost after iteration 100: 0.737019
# Cost after iteration 110: 0.441355
# Cost after iteration 120: 0.252278
# Cost after iteration 130: 0.205168
# Cost after iteration 140: 0.196168
# train accuracy: 92.816091954023 %
# test accuracy: 93.54838709677419 %

# %% [markdown]
# # Logistic Regression with Sklearn

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression(random_state = 42,max_iter= 150)
print("test accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_test.T, y_test.T)))
print("train accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_train.T, y_train.T)))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# test accuracy: 0.967741935483871
# train accuracy: 1.0
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # ANN

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Resmi yükleme
image_path = 'resim.jpg'  # Yüklemek istediğiniz resmin dosya yolu
image = Image.open("ANN.png")

# Resmi görüntüleme
plt.imshow(image)
plt.axis('off')  # Eksenleri kapatma
plt.show()

# %%
image2 = Image.open("ANN PNG.png")
plt.imshow(image2)
plt.axis('off')  # Eksenleri kapatma
plt.show()

# %% [markdown]
# # 2-Layer Neural Network

# %% [markdown]
# Size of layers and initializing parameters weights and bias
#
# Forward propagation
#
# Loss function and Cost function
#
# Backward propagation
#
# Update Parameters
#
# Prediction with learnt parameters weight and bias
#
# Create Model

# %% [markdown]
# # Size of layers and initializing parameters weights and bias

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Resmi açma
image3 = Image.open("resim.png")

# Görüntü boyutlarını ayarlayarak gösterme
plt.figure(figsize=(14, 8))  # Boyutları ayarlama (genişlik, yükseklik)
plt.imshow(image3)
plt.axis('off')  # Eksenleri kapatma
plt.show()

# %%
# intialize parameters and layer sizes
def initialize_parameters_and_layer_sizes_NN(x_train, y_train):
    parameters = {"weight1": np.random.randn(3,x_train.shape[0]) * 0.1,
                  "bias1": np.zeros((3,1)),
                  "weight2": np.random.randn(y_train.shape[0],3) * 0.1,
                  "bias2": np.zeros((y_train.shape[0],1))}
    return parameters

# %%
parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

print("weight1:")
print(parameters["weight1"])
print("\nbias1:")
print(parameters["bias1"])
print("\nweight2:")
print(parameters["weight2"])
print("\nbias2:")
print(parameters["bias2"])
# Out:
# weight1:
# [[-0.03162865  0.15409156  0.10157446 ... -0.12923023  0.03239616
#    0.0048923 ]
#  [ 0.03140586 -0.04369171 -0.10200809 ... -0.15996105  0.16970984
#    0.08995252]
#  [ 0.06198308 -0.03057912  0.03039114 ...  0.10195109 -0.13118982
#   -0.04635153]]
#
# bias1:
# [[0.]
#  [0.]
#  [0.]]
#
# weight2:
# [[ 0.01108161 -0.04178003  0.03572458]]
#
# bias2:
# [[0.]]

# %%
#bias2 nin tek 0 olması çıktı olarak tek outpu olduğu bias1 in 3 olması 3 node numaber olmasından kaynaklıdır

# %% [markdown]
# # Forward propagation

# %% [markdown]
# Forward propagation is almost same with logistic regression.
#
# The only difference is we use tanh function and we make all process twice.
#
# Also numpy has tanh function. So we do not need to implement it.

# %%
def forward_propagation_NN(x_train, parameters):

    Z1 = np.dot(parameters["weight1"],x_train) + parameters["bias1"]
    A1 = np.tanh(Z1)
    
    Z2 = np.dot(parameters["weight2"],A1) + parameters["bias2"]
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %% [markdown]
# # Loss function and Cost function

# %%
# Compute cost
def compute_cost_NN(A2, Y, parameters):
    logprobs = np.multiply(np.log(A2),Y)
    cost = -np.sum(logprobs)/Y.shape[1]
    return cost

# %% [markdown]
# # Backward propagation

# %% [markdown]
# As you know backward propagation means derivative.
#
# If you want to learn (as I said I cannot explain without talking bc it is little confusing), please watch video in youtube.
#
# However the logic is same, lets write code.

# %%
# Backward Propagation
def backward_propagation_NN(parameters, cache, X, Y):

    dZ2 = cache["A2"]-Y
    dW2 = np.dot(dZ2,cache["A1"].T)/X.shape[1]
    db2 = np.sum(dZ2,axis =1,keepdims=True)/X.shape[1]
    dZ1 = np.dot(parameters["weight2"].T,dZ2)*(1 - np.power(cache["A1"], 2))
    dW1 = np.dot(dZ1,X.T)/X.shape[1]
    db1 = np.sum(dZ1,axis =1,keepdims=True)/X.shape[1]
    grads = {"dweight1": dW1,
             "dbias1": db1,
             "dweight2": dW2,
             "dbias2": db2}
    return grads

# %% [markdown]
# # Update Parameters

# %%
# update parameters
def update_parameters_NN(parameters, grads, learning_rate = 0.01):
    parameters = {"weight1": parameters["weight1"]-learning_rate*grads["dweight1"],
                  "bias1": parameters["bias1"]-learning_rate*grads["dbias1"],
                  "weight2": parameters["weight2"]-learning_rate*grads["dweight2"],
                  "bias2": parameters["bias2"]-learning_rate*grads["dbias2"]}
    
    return parameters

# %% [markdown]
# # Prediction with learnt parameters weight and bias

# %%
# prediction
def predict_NN(parameters,x_test):
    # x_test is a input for forward propagation
    A2, cache = forward_propagation_NN(x_test,parameters)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(A2.shape[1]):
        if A2[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %%
# 2 - Layer neural network

def two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations):
    cost_list = []
    index_list = []
    #initialize parameters and layer sizes
    parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

    for i in range(0, num_iterations):
         # forward propagation
        A2, cache = forward_propagation_NN(x_train,parameters)
        # compute cost
        cost = compute_cost_NN(A2, y_train, parameters)
         # backward propagation
        grads = backward_propagation_NN(parameters, cache, x_train, y_train)
         # update parameters
        parameters = update_parameters_NN(parameters, grads)
        
        if i % 100 == 0:
            cost_list.append(cost)
            index_list.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
            
    plt.plot(index_list,cost_list)
    plt.xticks(index_list,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    
    # predict
    y_prediction_test = predict_NN(parameters,x_test)
    y_prediction_train = predict_NN(parameters,x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    return parameters

parameters = two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations=3400)
# Out:
# Cost after iteration 0: 0.367251
# Cost after iteration 100: 0.325950
# Cost after iteration 200: 0.313631
# Cost after iteration 300: 0.278849
# Cost after iteration 400: 0.234997
# Cost after iteration 500: 0.194298
# Cost after iteration 600: 0.202549
# Cost after iteration 700: 0.161211
# Cost after iteration 800: 0.127768
# Cost after iteration 900: 0.101737
# Cost after iteration 1000: 0.084583
# Cost after iteration 1100: 0.074719
# Cost after iteration 1200: 0.066972
# Cost after iteration 1300: 0.060728
# Cost after iteration 1400: 0.055624
# Cost after iteration 1500: 0.051401
# Cost after iteration 1600: 0.047867
# Cost after iteration 1700: 0.044880
# Cost after iteration 1800: 0.042326
# Cost after iteration 1900: 0.040115
# Cost after iteration 2000: 0.038172
# Cost after iteration 2100: 0.036435
# Cost after iteration 2200: 0.034851
# Cost after iteration 2300: 0.033368
# Cost after iteration 2400: 0.031937
# Cost after iteration 2500: 0.030509
# Cost after iteration 2600: 0.029049
# Cost after iteration 2700: 0.027574
# Cost after iteration 2800: 0.026154
# Cost after iteration 2900: 0.024856
# Cost after iteration 3000: 0.023688
# Cost after iteration 3100: 0.022614
# Cost after iteration 3200: 0.021576
# Cost after iteration 3300: 0.020502
# train accuracy: 99.42528735632185 %
# test accuracy: 93.54838709677419 %

# %%
# Resmi açma
image4 = Image.open("LLAYER.png")

# Görüntü boyutlarını ayarlayarak gösterme
plt.figure(figsize=(14, 8))  # Boyutları ayarlama (genişlik, yükseklik)
plt.imshow(image4)
plt.axis('off')  # Eksenleri kapatma
plt.show()

# %%
# reshaping
x_train, x_test, y_train, y_test = x_train.T, x_test.T, y_train.T, y_test.T

# %% [markdown]
# # Keras

# %%
# Evaluating the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential # initialize neural network library
from keras.layers import Dense # build our layers library

def build_classifier():
    classifier = Sequential() # initialize neural network
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/100
# /var/folders/sx/rybvq68145n15r0k_ggr9pn00000gn/T/ipykernel_18551/3097701138.py:15: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
# 2024-06-20 13:06:11.796176: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6932 - accuracy: 0.4957
# Epoch 2/100
# 8/8 [==============================] - 0s 919us/step - loss: 0.6930 - accuracy: 0.5431
# Epoch 3/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5431
# Epoch 4/100
# 8/8 [==============================] - 0s 995us/step - loss: 0.6926 - accuracy: 0.5431
# Epoch 5/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6925 - accuracy: 0.5431
# Epoch 6/100
# 8/8 [==============================] - 0s 974us/step - loss: 0.6924 - accuracy: 0.5431
# Epoch 7/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6923 - accuracy: 0.5431
# Epoch 8/100
# 8/8 [==============================] - 0s 938us/step - loss: 0.6923 - accuracy: 0.5431
# Epoch 9/100
# 8/8 [==============================] - 0s 909us/step - loss: 0.6921 - accuracy: 0.5431
# Epoch 10/100
# 8/8 [==============================] - 0s 959us/step - loss: 0.6921 - accuracy: 0.5431
# Epoch 11/100
# 8/8 [==============================] - 0s 956us/step - loss: 0.6920 - accuracy: 0.5431
# Epoch 12/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.5431
# Epoch 13/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6918 - accuracy: 0.5431
# Epoch 14/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6917 - accuracy: 0.5431
# Epoch 15/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.5431
# Epoch 16/100
# 8/8 [==============================] - 0s 913us/step - loss: 0.6916 - accuracy: 0.5431
# Epoch 17/100
# 8/8 [==============================] - 0s 919us/step - loss: 0.6915 - accuracy: 0.5431
# Epoch 18/100
# 8/8 [==============================] - 0s 991us/step - loss: 0.6914 - accuracy: 0.5431
# Epoch 19/100
# 8/8 [==============================] - 0s 947us/step - loss: 0.6913 - accuracy: 0.5431
# Epoch 20/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.5431
# Epoch 21/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6911 - accuracy: 0.5431
# Epoch 22/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6910 - accuracy: 0.5431
# Epoch 23/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6910 - accuracy: 0.5431
# Epoch 24/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5431
# Epoch 25/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5431
# Epoch 26/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 27/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 28/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 29/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5431
# Epoch 30/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5431
# Epoch 31/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6906 - accuracy: 0.5431
# Epoch 32/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.5431
# Epoch 33/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.5431
# Epoch 34/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.5431
# Epoch 35/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.5431
# Epoch 36/100
# 8/8 [==============================] - 0s 923us/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 37/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 38/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 39/100
# 8/8 [==============================] - 0s 975us/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 40/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 41/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 42/100
# 8/8 [==============================] - 0s 993us/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 43/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 44/100
# 8/8 [==============================] - 0s 966us/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 45/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 46/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 47/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 48/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 49/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 50/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 51/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 52/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 53/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 54/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 55/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 56/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 57/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 58/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 59/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 60/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 61/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 62/100
# 8/8 [==============================] - 0s 939us/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 63/100
# 8/8 [==============================] - 0s 944us/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 64/100
# 8/8 [==============================] - 0s 970us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 65/100
# 8/8 [==============================] - 0s 950us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 66/100
# 8/8 [==============================] - 0s 936us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 67/100
# 8/8 [==============================] - 0s 954us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 68/100
# 8/8 [==============================] - 0s 917us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 69/100
# 8/8 [==============================] - 0s 896us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 70/100
# 8/8 [==============================] - 0s 970us/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 71/100
# 8/8 [==============================] - 0s 950us/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 72/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 73/100
# 8/8 [==============================] - 0s 964us/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 74/100
# 8/8 [==============================] - 0s 918us/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 75/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 76/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 77/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 78/100
# 8/8 [==============================] - 0s 997us/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 79/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 80/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 81/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 82/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 83/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 84/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 85/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 86/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 87/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 88/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 89/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 90/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 91/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 92/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 93/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 95/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 96/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 97/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 98/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 99/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 100/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.5431
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7055 - accuracy: 0.4310
# Epoch 1/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.4698
# Epoch 2/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6920 - accuracy: 0.5216
# Epoch 3/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5216
# Epoch 4/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6890 - accuracy: 0.8017
# Epoch 5/100
# 8/8 [==============================] - 0s 986us/step - loss: 0.6866 - accuracy: 0.8836
# Epoch 6/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6839 - accuracy: 0.5259
# Epoch 7/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6797 - accuracy: 0.7155
# Epoch 8/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6689 - accuracy: 0.6853
# Epoch 9/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6571 - accuracy: 0.7500
# Epoch 10/100
# 8/8 [==============================] - 0s 960us/step - loss: 0.6372 - accuracy: 0.8060
# Epoch 11/100
# 8/8 [==============================] - 0s 953us/step - loss: 0.6111 - accuracy: 0.8707
# Epoch 12/100
# 8/8 [==============================] - 0s 952us/step - loss: 0.5927 - accuracy: 0.7026
# Epoch 13/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5468 - accuracy: 0.8233
# Epoch 14/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5249 - accuracy: 0.8060
# Epoch 15/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.8793
# Epoch 16/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.8707
# Epoch 17/100
# 8/8 [==============================] - 0s 991us/step - loss: 0.4000 - accuracy: 0.8922
# Epoch 18/100
# 8/8 [==============================] - 0s 927us/step - loss: 0.3703 - accuracy: 0.9052
# Epoch 19/100
# 8/8 [==============================] - 0s 942us/step - loss: 0.3371 - accuracy: 0.8879
# Epoch 20/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8922
# Epoch 21/100
# 8/8 [==============================] - 0s 974us/step - loss: 0.2832 - accuracy: 0.9397
# Epoch 22/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2703 - accuracy: 0.9483
# Epoch 23/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2392 - accuracy: 0.9483
# Epoch 24/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.9353
# Epoch 25/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2138 - accuracy: 0.9440
# Epoch 26/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9526
# Epoch 27/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.9569
# Epoch 28/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9483
# Epoch 29/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.9526
# Epoch 30/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1937 - accuracy: 0.9353
# Epoch 31/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1882 - accuracy: 0.9267
# Epoch 32/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1494 - accuracy: 0.9655
# Epoch 33/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1459 - accuracy: 0.9612
# Epoch 34/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1348 - accuracy: 0.9655
# Epoch 35/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9612
# Epoch 36/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1473 - accuracy: 0.9397
# Epoch 37/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9612
# Epoch 38/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9612
# Epoch 39/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1141 - accuracy: 0.9698
# Epoch 40/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1385 - accuracy: 0.9440
# Epoch 41/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1272 - accuracy: 0.9612
# Epoch 42/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1119 - accuracy: 0.9698
# Epoch 43/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9741
# Epoch 44/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0988 - accuracy: 0.9741
# Epoch 45/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0924 - accuracy: 0.9784
# Epoch 46/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0911 - accuracy: 0.9741
# Epoch 47/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9741
# Epoch 48/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9784
# Epoch 49/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0846 - accuracy: 0.9784
# Epoch 50/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9828
# Epoch 51/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9828
# Epoch 52/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0814 - accuracy: 0.9741
# Epoch 53/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9741
# Epoch 54/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0851 - accuracy: 0.9784
# Epoch 55/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 0.9655
# Epoch 56/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0873 - accuracy: 0.9655
# Epoch 57/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9871
# Epoch 58/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9828
# Epoch 59/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0752 - accuracy: 0.9784
# Epoch 60/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0678 - accuracy: 0.9828
# Epoch 61/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0690 - accuracy: 0.9784
# Epoch 62/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9871
# Epoch 63/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9828
# Epoch 64/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0558 - accuracy: 0.9871
# Epoch 65/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0540 - accuracy: 0.9828
# Epoch 66/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0584 - accuracy: 0.9871
# Epoch 67/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0520 - accuracy: 0.9871
# Epoch 68/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 0.9828
# Epoch 69/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 0.9914
# Epoch 70/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0580 - accuracy: 0.9784
# Epoch 71/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0491 - accuracy: 0.9914
# Epoch 72/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0494 - accuracy: 0.9871
# Epoch 73/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9871
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9914
# Epoch 75/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 0.9871
# Epoch 76/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9871
# Epoch 77/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9914
# Epoch 78/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9914
# Epoch 79/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9914
# Epoch 80/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9828
# Epoch 81/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0630 - accuracy: 0.9784
# Epoch 82/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0473 - accuracy: 0.9914
# Epoch 83/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 0.9871
# Epoch 84/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9957
# Epoch 85/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9871
# Epoch 86/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 87/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9957
# Epoch 88/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9914
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9957
# Epoch 90/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9957
# Epoch 91/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9914
# Epoch 92/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9957
# Epoch 93/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 94/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 0.9914
# Epoch 95/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 96/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9957
# Epoch 97/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 98/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9957
# Epoch 99/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9957
# Epoch 100/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 1.0000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1543 - accuracy: 0.9483
# Epoch 1/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6932 - accuracy: 0.4871
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.4741
# Epoch 3/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5388
# Epoch 4/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5043
# Epoch 5/100
# 8/8 [==============================] - 0s 956us/step - loss: 0.6928 - accuracy: 0.5259
# Epoch 6/100
# 8/8 [==============================] - 0s 965us/step - loss: 0.6926 - accuracy: 0.5129
# Epoch 7/100
# 8/8 [==============================] - 0s 961us/step - loss: 0.6922 - accuracy: 0.6983
# Epoch 8/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.8017
# Epoch 9/100
# 8/8 [==============================] - 0s 934us/step - loss: 0.6904 - accuracy: 0.7931
# Epoch 10/100
# 8/8 [==============================] - 0s 947us/step - loss: 0.6889 - accuracy: 0.6293
# Epoch 11/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6856 - accuracy: 0.6940
# Epoch 12/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6809 - accuracy: 0.5474
# Epoch 13/100
# 8/8 [==============================] - 0s 995us/step - loss: 0.6760 - accuracy: 0.4957
# Epoch 14/100
# 8/8 [==============================] - 0s 940us/step - loss: 0.6673 - accuracy: 0.6250
# Epoch 15/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.7328
# Epoch 16/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6489 - accuracy: 0.5948
# Epoch 17/100
# 8/8 [==============================] - 0s 929us/step - loss: 0.6371 - accuracy: 0.6422
# Epoch 18/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6275 - accuracy: 0.6724
# Epoch 19/100
# 8/8 [==============================] - 0s 968us/step - loss: 0.6107 - accuracy: 0.6724
# Epoch 20/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.6810
# Epoch 21/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7069
# Epoch 22/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5697 - accuracy: 0.7543
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5550 - accuracy: 0.7543
# Epoch 24/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5421 - accuracy: 0.7759
# Epoch 25/100
# 8/8 [==============================] - 0s 985us/step - loss: 0.5309 - accuracy: 0.7672
# Epoch 26/100
# 8/8 [==============================] - 0s 964us/step - loss: 0.5221 - accuracy: 0.8405
# Epoch 27/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5117 - accuracy: 0.8491
# Epoch 28/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4969 - accuracy: 0.7931
# Epoch 29/100
# 8/8 [==============================] - 0s 898us/step - loss: 0.4851 - accuracy: 0.8405
# Epoch 30/100
# 8/8 [==============================] - 0s 923us/step - loss: 0.4751 - accuracy: 0.8534
# Epoch 31/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4676 - accuracy: 0.8491
# Epoch 32/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.8879
# Epoch 33/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.8319
# Epoch 34/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8966
# Epoch 35/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.9267
# Epoch 36/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4274 - accuracy: 0.8966
# Epoch 37/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8836
# Epoch 38/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4226 - accuracy: 0.9267
# Epoch 39/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.9095
# Epoch 40/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4009 - accuracy: 0.9224
# Epoch 41/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.9052
# Epoch 42/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.9353
# Epoch 43/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3841 - accuracy: 0.8966
# Epoch 44/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3775 - accuracy: 0.9267
# Epoch 45/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3725 - accuracy: 0.9483
# Epoch 46/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3703 - accuracy: 0.9310
# Epoch 47/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3692 - accuracy: 0.9181
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.9483
# Epoch 49/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3554 - accuracy: 0.9310
# Epoch 50/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.9267
# Epoch 51/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.9483
# Epoch 52/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3453 - accuracy: 0.9612
# Epoch 53/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3387 - accuracy: 0.9526
# Epoch 54/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.9655
# Epoch 55/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.9612
# Epoch 56/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3261 - accuracy: 0.9526
# Epoch 57/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.9655
# Epoch 58/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3196 - accuracy: 0.9612
# Epoch 59/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3150 - accuracy: 0.9612
# Epoch 60/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3135 - accuracy: 0.9569
# Epoch 61/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3139 - accuracy: 0.9612
# Epoch 62/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 0.9095
# Epoch 63/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3344 - accuracy: 0.9784
# Epoch 64/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3110 - accuracy: 0.9440
# Epoch 65/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.9741
# Epoch 66/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2998 - accuracy: 0.9741
# Epoch 67/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2946 - accuracy: 0.9612
# Epoch 68/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2934 - accuracy: 0.9698
# Epoch 69/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.9612
# Epoch 70/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.9828
# Epoch 71/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2883 - accuracy: 0.9569
# Epoch 72/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3138 - accuracy: 0.9698
# Epoch 73/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.9397
# Epoch 74/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3009 - accuracy: 0.9784
# Epoch 75/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2891 - accuracy: 0.9397
# Epoch 76/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.9828
# Epoch 77/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.9612
# Epoch 78/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2718 - accuracy: 0.9828
# Epoch 79/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9741
# Epoch 80/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2666 - accuracy: 0.9612
# Epoch 81/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.9784
# Epoch 82/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.9698
# Epoch 83/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2590 - accuracy: 0.9871
# Epoch 84/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9741
# Epoch 85/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2550 - accuracy: 0.9828
# Epoch 86/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9784
# Epoch 87/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2534 - accuracy: 0.9698
# Epoch 88/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.9698
# Epoch 89/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2561 - accuracy: 0.9655
# Epoch 90/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2621 - accuracy: 0.9784
# Epoch 91/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.9871
# Epoch 92/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.9741
# Epoch 93/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2417 - accuracy: 0.9914
# Epoch 94/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.9698
# Epoch 95/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2345 - accuracy: 0.9828
# Epoch 96/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9698
# Epoch 97/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2335 - accuracy: 0.9871
# Epoch 98/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9871
# Epoch 99/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9784
# Epoch 100/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.9828
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.9138
# Accuracy mean: 0.76436780889829
# Accuracy variance: 0.23612228302694846
